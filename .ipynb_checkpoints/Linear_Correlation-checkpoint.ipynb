# %%
import os
import numpy as np
import mne
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr

# %%
"""This work will be used to
1-	Read all Experiment Data 
2-	Separate Channels into Matrices (Subject x SignalinTime)
3-	Find breaks in time of the experiment
a.	When an evoked signal started/ended
4-	Break the matrices into experiment moments
a.	Evoked Sound
b.	Evoked Visual
5-	Calculate feature stdvar for each step of experiment in each channel of each subject
6-	Calculate linear correlation between subjects
"""
# Out:
# 'This work will be used to\n1-\tRead all Experiment Data \n2-\tSeparate Channels into Matrices (Subject x SignalinTime)\n3-\tFind breaks in time of the experiment\na.\tWhen an evoked signal started/ended\n4-\tBreak the matrices into experiment moments\na.\tEvoked Sound\nb.\tEvoked Visual\n5-\tCalculate feature stdvar for each step of experiment in each channel of each subject\n6-\tCalculate linear correlation between subjects\n'

# %%
#Read the files and add to an eegraw vector of EEGLAB objects
class pp:

    def read_eeg(dataset_path):
        """
            Method to read the eeg from a folder, 
            the OS liberary do a crawling on the selected
            folder while mne.io.read_raw_eeglab reads the 
            egg in eeglab format
            
            Args:
                dataset_path = String with dataset path for the images
            
            Return:
                images = List with eegs in eeglab raw format
        """
        eegraw = []
        filename = []
        for path, subdir, files in os.walk(dataset_path):
                for file in files:
                    if file[-3:] == "set":
                        raw = mne.io.read_raw_eeglab(f"{path}/{file}")
                        eegraw.append(raw)
                        filename.append(file)
        
        return eegraw, filename

#raw = mne.io.read_raw_eeglab('/Users/viniciussilvestrelourenco/Desktop/eegexperiment/sub-001/eeg/sub-001_task-Experiment_eeg.set', preload=True)

# %%
"""
1- Read All Experiment Data Into a main RAW Vector
"""
#Read
dataset_path = "data"
eegraw, filename = pp.read_eeg(dataset_path)
# Out:
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-010/eeg/sub-010_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-017/eeg/sub-017_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-016/eeg/sub-016_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-011/eeg/sub-011_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-018/eeg/sub-018_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-002/eeg/sub-002_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-005/eeg/sub-005_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-004/eeg/sub-004_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-003/eeg/sub-003_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-014/eeg/sub-014_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-013/eeg/sub-013_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-012/eeg/sub-012_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-015/eeg/sub-015_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-006/eeg/sub-006_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-001/eeg/sub-001_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-008/eeg/sub-008_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-009/eeg/sub-009_task-Experiment_eeg.fdt
# Reading /Users/viniciussilvestrelourenco/Documents/GitHub/EEGLinearCorrelation/data/sub-007/eeg/sub-007_task-Experiment_eeg.fdt

# %%
# Test if Read Worked
eegraw[3].info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: FP1, FPZ, FP2, F7, F3, FZ, F4, F8, FC5, FC1, FC2, FC6, M1, T7, ...
#  chs: 32 EEG
#  custom_ref_applied: False
#  dig: 32 items (32 EEG)
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 32
#  projs: []
#  sfreq: 256.0 Hz
# >

# %%
#Plotting
eegraw[0].plot_psd(fmax=50)
eegraw[0].plot(duration=5, n_channels=64)
# Out:
# Effective window size : 8.000 (s)
# <MNELineFigure size 720x252 with 2 Axes>
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
#Test if file name saver worked:
subject = []
for file in filename:
    print(file)
    subject.append(file[5:7])

for subj in subject:
    print(subj)
# Out:
# sub-010_task-Experiment_eeg.set
# sub-017_task-Experiment_eeg.set
# sub-016_task-Experiment_eeg.set
# sub-011_task-Experiment_eeg.set
# sub-018_task-Experiment_eeg.set
# sub-002_task-Experiment_eeg.set
# sub-005_task-Experiment_eeg.set
# sub-004_task-Experiment_eeg.set
# sub-003_task-Experiment_eeg.set
# sub-014_task-Experiment_eeg.set
# sub-013_task-Experiment_eeg.set
# sub-012_task-Experiment_eeg.set
# sub-015_task-Experiment_eeg.set
# sub-006_task-Experiment_eeg.set
# sub-001_task-Experiment_eeg.set
# sub-008_task-Experiment_eeg.set
# sub-009_task-Experiment_eeg.set
# sub-007_task-Experiment_eeg.set
# 10
# 17
# 16
# 11
# 18
# 02
# 05
# 04
# 03
# 14
# 13
# 12
# 15
# 06
# 01
# 08
# 09
# 07

# %%
#Find Index of each Subject number
index = []
i=1
while i <= len(subject):
    j=0
    for subj in subject:
        if i < 10:
            k = f'0{i}'
            if subj == k:
                index.append(j)
                print(j)
            else:
                j+=1
        else:
            if subj == str(i):
                index.append(j)
                print(j)
            else:
                j+=1
    i+=1
    
# Index[0] is the index position of subject 01.
# Out:
# 14
# 5
# 8
# 7
# 6
# 13
# 17
# 15
# 16
# 0
# 3
# 11
# 10
# 9
# 12
# 2
# 1
# 4

# %%
"""
2- Separate Channels into Matrices
"""
#Build a Channels Dictionary
chn_dict = {
    1:'Fp1', 
    2:'AF7',
    3:'AF3',
    4:'F1', 
    5:'F3', 
    6:'F5', 
    7:'F7', 
    8:'FT7', 
    9:'FC5', 
    10:'FC3',
    11:'FC1', 
    12:'C1', 
    13:'C3', 
    14:'C5', 
    15:'T7', 
    16:'TP7',
    17:'CP5', 
    18:'CP3', 
    19:'CP1', 
    20:'P1', 
    21:'P3', 
    22:'P5',
    23:'P7', 
    24:'P9',
    25:'PO7',
    26:'PO3',
    27:'O1', 
    28:'Iz', 
    29:'Oz', 
    30:'POz',
    31:'Pz', 
    32:'CPz',
    33:'Fpz',
    34:'Fp2', 
    35:'AF8', 
    36:'AF4', 
    37:'Afz', 
    38:'Fz', 
    39:'F2', 
    40:'F4', 
    41:'F6', 
    42:'F8', 
    43:'FT8',
    44:'FC6', 
    45:'FC4', 
    46:'FC2', 
    47:'FCz', 
    48:'Cz', 
    49:'C2', 
    50:'C4', 
    51:'C6', 
    52:'T8', 
    53:'TP8', 
    54:'CP6', 
    55:'CP4', 
    56:'CP2',
    57:'P2', 
    58:'P4', 
    59:'P6', 
    60:'P8', 
    61:'P10',
    62:'PO8', 
    63:'PO4',
    64:'O2'
}

# %%
#Create Matrix Subject x Channel

matrix = [[0 for x in range(len(chn_dict))] for y in range(len(subject))]
np.shape(matrix)
# Out:
# (18, 64)

# %%
#Select 1 channel 
chn_dict[index[1]]
# Out:
# 'F3'

# %%
#Isolate 1 channel

## Copy Channel names list into a vector
ch_list = eegraw[1].ch_names.copy()
print(ch_list)
sub0 = eegraw[15].copy()

## Remove all Channels except the desired one from the subject data

## Remove the desired channel from the list
"""
ch_list.remove(chn_dict[1])
print(ch_list)


print('Number of channels in subject:')
print(len(sub0.ch_names), end=' → drop to 1 → ')
sub0.drop_channels(ch_list)
print(len(sub0.ch_names))
print(sub0.ch_names)
"""

#Other Possibility is to use pick_channels and select the desired one directly
sub0.pick_channels([chn_dict[7]])
print(sub0.ch_names)
# Out:
# ['FP1', 'FPZ', 'FP2', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'M1', 'T7', 'C3', 'CZ', 'C4', 'T8', 'M2', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'PZ', 'P4', 'P8', 'POZ', 'O1', 'OZ', 'O2']
# ['F7']

# %%
print(sub0)
# Out:
# <RawEEGLAB | sub-008_task-Experiment_eeg.fdt, 1 x 802928 (3136.4 s), ~19 kB, data not loaded>

# %%
# Extracting Data from the Isolated Channel for 1 Subject

sampling_freq = sub0.info['sfreq']
start_stop_seconds = np.array([1.6, 3.2])
start_sample, stop_sample = (start_stop_seconds * sampling_freq).astype(int)
channel_index = 0
raw_selection = sub0[channel_index, start_sample:stop_sample]
print(raw_selection)

## Plotting the extracted data

### time dimension
x = raw_selection[1]

### data dimension
y = raw_selection[0].T
plt.plot(x, y)
plt.xlabel('Time')
plt.ylabel('Data')
plt.title('Plot of channel 0')
# Out:
# (array([[-0.01900407, -0.01900823, -0.0190038 , -0.01900241, -0.01900943,
#         -0.01900735, -0.01901376, -0.01902403, -0.01902418, -0.01903287,
#         -0.01902709, -0.01901849, -0.01900171, -0.01899788, -0.01900485,
#         -0.01901895, -0.019029  , -0.01901171, -0.01900697, -0.01900461,
#         -0.01899836, -0.01899655, -0.01899321, -0.01900258, -0.01900734,
#         -0.0190015 , -0.01900357, -0.01899661, -0.01900903, -0.0190133 ,
#         -0.01899056, -0.01900091, -0.01900501, -0.01900622, -0.01900757,
#         -0.01900532, -0.01902984, -0.0190261 , -0.0190169 , -0.01901651,
#         -0.01900261, -0.01900501, -0.0190146 , -0.0190223 , -0.01902167,
#         -0.01902349, -0.01903941, -0.01901633, -0.01898923, -0.01899663,
#         -0.01898773, -0.01897424, -0.01897898, -0.01899741, -0.01900799,
#         -0.01900337, -0.01898952, -0.01898971, -0.01900194, -0.01899449,
#         -0.0189823 , -0.0189762 , -0.0189787 , -0.01899552, -0.01901772,
#         -0.01903689, -0.0190364 , -0.01901017, -0.01899079, -0.01900238,
#         -0.01901569, -0.01901821, -0.01901104, -0.01899023, -0.01898853,
#         -0.01899361, -0.01900129, -0.01900455, -0.01899156, -0.01899932,
#         -0.01899099, -0.01897549, -0.01898112, -0.01898468, -0.01899295,
#         -0.01900067, -0.0189955 , -0.01897705, -0.0189718 , -0.01897479,
#         -0.01897083, -0.01897285, -0.01898   , -0.01898472, -0.01899365,
#         -0.01900322, -0.01901627, -0.01903619, -0.01901734, -0.01898222,
#         -0.01896439, -0.01895801, -0.01895588, -0.01896629, -0.01896895,
#         -0.01895767, -0.01897387, -0.01896637, -0.01895439, -0.01896366,
#         -0.01896087, -0.01896252, -0.01895608, -0.01895441, -0.01895914,
#         -0.01895334, -0.01895959, -0.01897404, -0.01897401, -0.01896507,
#         -0.01895447, -0.01895658, -0.01896266, -0.01897432, -0.01899018,
#         -0.01898313, -0.01897018, -0.0189596 , -0.0189626 , -0.0189648 ,
#         -0.01895167, -0.01895713, -0.01897324, -0.01897149, -0.01895084,
#         -0.01894063, -0.0189587 , -0.01897063, -0.01897381, -0.01898648,
#        2.90625   , 2.91015625, 2.9140625 , 2.91796875, 2.921875  ,
#        2.92578125, 2.9296875 , 2.93359375, 2.9375    , 2.94140625,
#        2.9453125 , 2.94921875, 2.953125  , 2.95703125, 2.9609375 ,
#        2.96484375, 2.96875   , 2.97265625, 2.9765625 , 2.98046875,
#        2.984375  , 2.98828125, 2.9921875 , 2.99609375, 3.        ,
#        3.00390625, 3.0078125 , 3.01171875, 3.015625  , 3.01953125,
#        3.0234375 , 3.02734375, 3.03125   , 3.03515625, 3.0390625 ,
#        3.04296875, 3.046875  , 3.05078125, 3.0546875 , 3.05859375,
#        3.0625    , 3.06640625, 3.0703125 , 3.07421875, 3.078125  ,
#        3.08203125, 3.0859375 , 3.08984375, 3.09375   , 3.09765625,
#        3.1015625 , 3.10546875, 3.109375  , 3.11328125, 3.1171875 ,
#        3.12109375, 3.125     , 3.12890625, 3.1328125 , 3.13671875,
#        3.140625  , 3.14453125, 3.1484375 , 3.15234375, 3.15625   ,
#        3.16015625, 3.1640625 , 3.16796875, 3.171875  , 3.17578125,
#        3.1796875 , 3.18359375, 3.1875    , 3.19140625, 3.1953125 ]))
# Text(0.5, 1.0, 'Plot of channel 0')

# %%
#Trying to use FFT

fft = np.fft.ifft(raw_selection[1])
y = fft
plt.plot(y)
plt.ylabel('Data')
plt.title('Plot of channel 0')
# Out:
# /Users/viniciussilvestrelourenco/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Plot of channel 0')

# %%
#Trying Spectogram
from scipy import signal

f, t, Sxx = signal.spectrogram(x, y)

plt.pcolormesh(t, f, Sxx, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-8ddcdf4b95fb> in <module>
#       2 from scipy import signal
#       3
# ----> 4 f, t, Sxx = signal.spectrogram(x, y)
#       5
#       6 plt.pcolormesh(t, f, Sxx, shading='gouraud')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/signal/spectral.py in spectrogram(x, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode)
#     743
#     744     if mode == 'psd':
# --> 745         freqs, time, Sxx = _spectral_helper(x, x, fs, window, nperseg,
#     746                                             noverlap, nfft, detrend,
#     747                                             return_onesided, scaling, axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/signal/spectral.py in _spectral_helper(x, y, fs, window, nperseg, noverlap, nfft, detrend, return_onesided, scaling, axis, mode, boundary, padded)
#    1825         freqs = sp_fft.fftfreq(nfft, 1/fs)
#    1826     elif sides == 'onesided':
# -> 1827         freqs = sp_fft.rfftfreq(nfft, 1/fs)
#    1828
#    1829     # Perform the windowed FFTs
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/fft/helper.py in rfftfreq(n, d)
#     220     N = n//2 + 1
#     221     results = arange(0, N, dtype=int)
# --> 222     return results * val
#
# ValueError: operands could not be broadcast together with shapes (129,) (410,)

# %%
# Fulfill Matrix
"""
Method to create a matrix of subjects x channels
extract the information from eeglab files and then
fulfill the matrix that will be used later

Args:
    eegraw = list with eeglab raw data for each subject
    index  = Position of a given subject data in the eegraw file in crescent order of subjects (from 0 up to 18)
    subject = list with 
    

Return:
    matrix = [subject][channels] numpy array containing EEG channels data
"""

verbose = 0

#Create matrix to be fulfilled
matrix = [[0 for x in range(len(chn_dict))] for y in range(len(index))]
if verbose == 1:
    print(np.shape(matrix))

#Iterate over subjects i and channels j 
i=0
j=1

while i < len(index):
    while j <= len(chn_dict):
        k = j-1
        #Copy Index Raw
        subraw = eegraw[index[i]].copy()
        if verbose ==1:
            print(subraw.info)
        
        #Pick Desired Channel
        subraw.pick_channels([chn_dict[j]])
        if verbose == 1:
            print(subraw.ch_names)
        
        #Isolate data into raw_selection
        sampling_freq = subraw.info['sfreq']
        start_stop_seconds = np.array([0, 5000])
        start_sample, stop_sample = (start_stop_seconds * sampling_freq).astype(int)
        channel_index = 0
        raw_selection = subraw[channel_index, start_sample:stop_sample]
        
        if verbose == 1:
            print(raw_selection)
        
        matrix[i][k] = raw_selection
        
        ###Plot extracted data
        #### time dimension
        #x = raw_selection[1]
        #
        #### data dimension
        #y = raw_selection[0].T
        #plt.plot(x, y)
        #plt.xlabel('Time')
        #plt.ylabel('Data')
        #plt.title('Plot of channel 0')
        j+=1
    j=1
    i+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-e15cf616c3d5> in <module>
#      35
#      36         #Pick Desired Channel
# ---> 37         subraw.pick_channels([chn_dict[j]])
#      38         if verbose == 1:
#      39             print(subraw.ch_names)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mne/channels/channels.py in pick_channels(self, ch_names, ordered)
#     819         """
#     820         picks = pick_channels(self.info['ch_names'], ch_names, ordered=ordered)
# --> 821         return self._pick_drop_channels(picks)
#     822
#     823     @verbose
#
# <decorator-gen-41> in _pick_drop_channels(self, idx, verbose)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mne/channels/channels.py in _pick_drop_channels(self, idx, verbose)
#     947             self._cals = self._cals[idx]
#     948
# --> 949         pick_info(self.info, idx, copy=False)
#     950
#     951         for key in ('_comp', '_projector'):
#
# <decorator-gen-7> in pick_info(info, sel, copy, verbose)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mne/io/pick.py in pick_info(info, sel, copy, verbose)
#     536         return info
#     537     elif len(sel) == 0:
# --> 538         raise ValueError('No channels match the selection.')
#     539     n_unique = len(np.unique(np.arange(len(info['ch_names']))[sel]))
#     540     if n_unique != len(sel):
#
# ValueError: No channels match the selection.

# %%
print(np.std(matrix[1][2][0]))
verbose = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-991861624d30> in <module>
# ----> 1 print(np.std(matrix[1][2][0]))
#       2 verbose = 1
#
# TypeError: 'int' object is not subscriptable

# %%
#Calculate a Matrix of the Standard Deviatons from the Subject x Channels data 

## Define a std_matrix with shape (#subjects x #channels)
std_matrix = np.zeros((int(len(matrix)),int(len(matrix[0]))))
if verbose = 1:
    print(np.shape(std_matrix)[0])

## Loop through the matrix calculating the stdev of each channel for each subject
i = 0
while i < np.shape(std_matrix)[0]:
    j = 0
    while j < np.shape(std_matrix)[1]:
        std_matrix[i][j] = np.std(matrix[i][j][0])
        if verbose == 1:
            print(f'i = {i} , j = {j} , {std_matrix[i][j]}')
        j+=1
    i+=1
# Out:
#   File "<ipython-input-30-9526d3995dbf>", line 5
#     if verbose = 1:
#                ^
# SyntaxError: invalid syntax

# %%
#Calculate Correlation between 2 vectors
   
a = [1,4,6,5]
b = [1,2,3,4]   
print(pearsonr(a,b))

#Calculate Correlation between 2 channels

print(pearsonr(matrix[1][1][0][0], matrix[1][31][0][0]))
# Out:
# (0.8366600265340756, 0.16333997346592444)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-27e6d9e245ba> in <module>
#       7 #Calculate Correlation between 2 channels
#       8
# ----> 9 print(pearsonr(matrix[1][1][0][0], matrix[1][31][0][0]))
#
# TypeError: 'int' object is not subscriptable
